# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1) df_tips içindeki Payment ID column'unun son 3 rakamını çekin. Bu işlemi 3 farklı yolla da yapmaya çalışın.

# %%
df_tips= pd.read_csv('tips.csv')
df_tips['Payment ID'].astype(str).str[-3:]
# Out:
# 0      959
# 1      608
# 2      458
# 3      260
# 4      251
#       ...
# 239    657
# 240    766
# 241    880
# 242    t17
# 243    672
# Name: Payment ID, Length: 244, dtype: object

# %% [markdown]
# 2) df_tips içindeki Payer Name sütununda isim ve soy isim bilgileri bulunuyor. O sütundan sadece isim bilgileri çekin ve 'JustName' adında yeni bir column oluşturun. (Bu biraz zorlayıcı olabilir, Önce kendiniz yapmaya çalışın fakat yapamazsanız ChatGPT'ye soruyu düzgünce sorarak cevabını kod olarak alabilirsiniz, ardından döndürülen kodu anlamaya çalışmanız yeterlidir.)

# %%
df_tips['JustName'] = df_tips['Payer Name'].str.split(' ')
df_tips['JustName'] = df_tips['JustName'].str[0]
df_tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID   JustName
# 0  Christy Cunningham  3560325168603410    Sun2959    Christy
# 1      Douglas Tucker  4478071379779230    Sun4608    Douglas
# 2      Travis Walters  6011812112971322    Sun4458     Travis
# 3    Nathaniel Harris  4676137647685994    Sun5260  Nathaniel
# 4        Tonya Carter  4832732618637221    Sun2251      Tonya

# %% [markdown]
# 3) 2.Soruda yeni oluşturduğunuz 'JustName' sütunundaki verilerin her birinden kaç tane olduğuna uygun methodu kullanarak bakın.

# %%
df_tips['JustName'].value_counts()
# Out:
# Jason          9
# Michael        7
# James          6
# David          6
# Christopher    5
#               ..
# Shawna         1
# Louis          1
# Chris          1
# Mark           1
# Michelle       1
# Name: JustName, Length: 153, dtype: int64

# %% [markdown]
# 4) 3.Soruda gördüğünüz gibi JustName sütununda 'Jason' isminden 9 tane, 'Michael' isminden 7 tane , 'James' isminden 6 tane bulunuyor. Peki bunların hepsi gerçekten farklı kişiler mi ? Hemen 'Payer Name' sütunundaki verilerin adetlerini de saydırtarak bir kıyaslama yapın. 'JustName' sütununu kullanmanın faydasız ve yanıltıcı olabileceğini görün ardından oluşturduğumuz 'JustName' sütununu kalıcı olarak drop edin. (Oluşturmanız için bir pratikti bu sütun sadece :D)

# %%
df_tips['Payer Name'].value_counts()
# Out:
# Christy Cunningham    1
# Todd Patterson        1
# Madison Wilson        1
# Ryan Gonzales         1
# Laura Robles          1
#                      ..
# Shawna Cook           1
# Derek Thomas          1
# Donald Williams       1
# Roger Taylor          1
# Michelle Hardin       1
# Name: Payer Name, Length: 244, dtype: int64

# %%
df_tips.drop('JustName', axis=1,inplace=True)
df_tips.head(7)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251
# 5          Erik Smith   213140353657882    Sun9679
# 6  Kristopher Johnson  2223727524230344    Sun5985

# %% [markdown]
# 5) Erkeklerin ve kadınların davranış patternlerini ayrı ayrı inceleyip yorumda bulunabilmek için 'df_male' ve 'df_female' adında 2 dataframe oluşturun. Birinde sadece 157 erkek verisi, diğerinde sadece 87 kadın verisi bulunsun.

# %%
df_male = df_tips[df_tips['sex'] =='Male']
df_male.reset_index(inplace = True,drop=True)
df_male.sample(20)
# Out:
#      total_bill   tip   sex smoker   day    time  size  price_per_person  \
# 123       15.69  1.50  Male    Yes   Sun  Dinner     2              7.84
# 81        29.93  5.07  Male     No   Sun  Dinner     4              7.48
# 111       32.90  3.11  Male    Yes   Sun  Dinner     2             16.45
# 37        18.04  3.00  Male     No   Sun  Dinner     2              9.02
# 145       13.28  2.72  Male     No   Sat  Dinner     2              6.64
# 15        39.42  7.58  Male     No   Sat  Dinner     4              9.86
# 9         15.42  1.57  Male     No   Sun  Dinner     2              7.71
# 25        16.31  2.00  Male     No   Sat  Dinner     3              5.44
# 110       16.82  4.00  Male    Yes   Sun  Dinner     2              8.41
# 92         7.51  2.00  Male     No  Thur   Lunch     2              3.76
# 126       16.58  4.00  Male    Yes  Thur   Lunch     2              8.29
# 75        20.49  4.06  Male    Yes   Sat  Dinner     2             10.24
# 7         14.78  3.23  Male     No   Sun  Dinner     2              7.39
# 51        20.23  2.01  Male     No   Sat  Dinner     2             10.12
# 12        16.29  3.71  Male     No   Sun  Dinner     3              5.43
# 148       11.61  3.39  Male     No   Sat  Dinner     2              5.80
# 90        41.19  5.00  Male     No  Thur   Lunch     5              8.24
# 16        19.82  3.18  Male     No   Sat  Dinner     2              9.91
# 29        17.46  2.54  Male     No   Sun  Dinner     2              8.73
# 27        31.27  5.00  Male     No   Sat  Dinner     3             10.42
#
#                 Payer Name         CC Number Payment ID
# 123           Riley Barnes   180053549128800    Sun5104
# 81             Shawn Blake  4689079711213722      Sun22
# 111        Nathan Reynolds   370307040837149    Sun5109
# 37            William Roth  6573923967142503    Sun9774
# 145            Glenn Jones      502061651712    Sat2937
# 15          Lance Peterson  3542584061609808     Sat239
# 9          Chad Harrington      577040572932    Sun1300
# 25            William Ford  3527691170179398    Sat9139
# 110            Brian Miles  3586342145399277    Sun7621
# 92          Daniel Robbins  4823139288341889   Thur6321
# 126         Benjamin Weber      676210011505   Thur9318
# 75           Karl Mcdaniel   180024452771522    Sat7865
# 7            Jerome Abbott  3532124519049786    Sun3775
# 51   Mr. Travis Bailey Jr.       60406789937     Sat561
# 12            John Pittman  6521340257218708    Sun2998
# 148           James Taylor  6011482917327995    Sat2124
# 90            Eric Andrews  4356531761046453   Thur3621
# 16        Christopher Ross    36739148167928    Sat6236
# 29             David Boyer  3536678244278149    Sun9460
# 27       Mr. Brandon Berry  6011525851069856    Sat6373

# %%
df_female = df_tips[df_tips['sex'] =='Female']
df_female.reset_index(inplace = True,drop=True)
df_female
# Out:
#     total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0        16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1        24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 2        35.26  5.00  Female     No   Sun  Dinner     4              8.82
# 3        14.83  3.02  Female     No   Sun  Dinner     2              7.42
# 4        10.33  1.67  Female     No   Sun  Dinner     3              3.44
# ..         ...   ...     ...    ...   ...     ...   ...               ...
# 82       10.09  2.00  Female    Yes   Fri   Lunch     2              5.04
# 83       22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
# 84       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 85       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 86       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#             Payer Name         CC Number Payment ID
# 0   Christy Cunningham  3560325168603410    Sun2959
# 1         Tonya Carter  4832732618637221    Sun2251
# 2         Diane Macias  4577817359320969    Sun6686
# 3        Vanessa Jones    30016702287574    Sun3848
# 4     Elizabeth Foster  4240025044626033    Sun9715
# ..                 ...               ...        ...
# 82          Ruth Weiss  5268689490381635    Fri6359
# 83    Jennifer Russell     4793003293608    Sat3943
# 84      Kimberly Crane      676184013727    Sat9777
# 85      Monica Sanders  3506806155565404    Sat1766
# 86     Michelle Hardin  3511451626698139    Thur672
#
# [87 rows x 11 columns]

# %% [markdown]
# 6) Ardından bu 'df_male' ile 'df_female' 'in ödedikleri bahşişler toplamını bulup karşılaştırın.

# %%
np.sum(df_male[['tip']])
# Out:
# tip    485.07
# dtype: float64

# %%
np.sum(df_female[['tip']])
# Out:
# tip    246.51
# dtype: float64

# %% [markdown]
# 7) 6.Soruda erkeklerin ve kadınların ödedikleri bahşişler toplamına bakıldığında Erkeklerin kadınlara kıyasla toplamda daha çok bahşiş ödediğini görüyoruz. Fakat biz biliyoruz ki bizim verimizde 157 Erkek, 87 kadın verisi vardı. Dolayısıyla Erkek sayısı daha fazla olduğu için toplam ödeyecekleri bahşiş miktarlarında da daha fazla çıkması oldukça normal bir durum. Bu yüzden daha mantıklı bir çıkarım için bu sefer df_male ile df_female'in bahşiş ORTALAMALARIN'a bakıp kıyaslayın, aralarında anlamlı ve ciddi bir fark var mı ?

# %%
np.average(df_male['tip'])
# Out:
# 3.0896178343949043

# %%
np.average(df_female['tip'])
# Out:
# 2.8334482758620685

# %% [markdown]
# 8) Oluşturmuş olduğunuz df_male ile çalışarak elimizdeki verideki erkeklerin yüzde kaçının sigara içtiğini bulun. Aynı şekilde elimizdeki kadınların yüzde kaçının sigara içtiğini de bulun. Aralarında anlamlı bir fark mı yorumlayın.

# %%
Smoker_Y=len(df_male[df_male['smoker'] == 'Yes'])
Smoker_Y/len(df_male)*100
# Out:
# 38.21656050955414

# %% [markdown]
# 9) Erkeklerin zaman olarak dinnerda mı yoksa lunch'da mı daha fazla yemek yediğini yüzdesel olarak bulun. Aynı işlemi kadınlar için de yapın. Yüzdesel olarak erkeklerin ve kadınların yemek yeme vakitleri arasında anlamlı bir fark var mı yok mu yorumlayın.

# %%
time_d=len(df_male[df_male['time']=='Dinner'])
dinner_yzd=time_d/len(df_male)*100
dinner_yzd
# Out:
# 78.98089171974523

# %%
time_d=len(df_female[df_female['time']=='Dinner'])
dinner_yzd=time_d/len(df_female)*100
dinner_yzd
# Out:
# 59.77011494252874

# %% [markdown]
# 10) CC Number sütununu kalıcı olarak drop edin. Ardından df'in içindeki sütunların birbirleriyle olan ilişkilerini inceleyin ve çıkan sonuçlar hakkında yorumlarınızı belirtin.

# %%
df_tips.drop('CC Number',axis=1,inplace=True)
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name Payment ID
# 0    Christy Cunningham    Sun2959
# 1        Douglas Tucker    Sun4608
# 2        Travis Walters    Sun4458
# 3      Nathaniel Harris    Sun5260
# 4          Tonya Carter    Sun2251
# ..                  ...        ...
# 239       Michael Avila    Sat2657
# 240      Monica Sanders    Sat1766
# 241          Keith Wong    Sat3880
# 242        Dennis Dixon      Sat17
# 243     Michelle Hardin    Thur672
#
# [244 rows x 10 columns]

# %%
df_tips.corr()
# Out:
#                   total_bill       tip      size  price_per_person
# total_bill          1.000000  0.675734  0.598315          0.647554
# tip                 0.675734  1.000000  0.489299          0.347405
# size                0.598315  0.489299  1.000000         -0.175359
# price_per_person    0.647554  0.347405 -0.175359          1.000000
